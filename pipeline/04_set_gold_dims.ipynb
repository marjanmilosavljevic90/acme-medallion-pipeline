# %%
from utils.logger import get_logger
from etl_config.gold_dim_config import DIM_CONFIG

logger = get_logger("set_gold_dims")

# %%
gold_dims = list(DIM_CONFIG.keys())
logger.info(f"Gold dimensions to process: {gold_dims}")

dbutils.jobs.taskValues.set(key="gold_dims", value=gold_dims)
logger.info(f"Task value 'gold_dims' set with {len(gold_dims)} dimensions.")
