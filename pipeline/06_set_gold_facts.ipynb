# %%
from utils.logger import get_logger
from etl_config.gold_fact_config import FACT_CONFIG

logger = get_logger("set_gold_facts")

# %%
gold_facts = list(FACT_CONFIG.keys())
logger.info(f"Gold facts to process: {gold_facts}")

dbutils.jobs.taskValues.set(key="gold_facts", value=gold_facts)
logger.info(f"Task value 'gold_facts' set with {len(gold_facts)} facts.")
