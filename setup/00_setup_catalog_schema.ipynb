# %% [markdown]
# ### Create Catalog

# %%
# %sql
create catalog if not exists acme_catalog;

# %% [markdown]
# ### Create Schemas

# %%
# %sql
create schema if not exists acme_catalog.landing;
create schema if not exists acme_catalog.bronze;
create schema if not exists acme_catalog.silver;
create schema if not exists acme_catalog.gold;

# %% [markdown]
# ### Create Volume

# %%
# %sql
create volume if not exists acme_catalog.landing.raw_files
comment 'Volume for raw ACME files in this case Excel';

# %%
# %sql
show schemas in acme_catalog;

# %%
# %sql
DESCRIBE CATALOG EXTENDED acme_catalog;

# %%
# %sql
# drop catalog if exists acme_catalog cascade;
